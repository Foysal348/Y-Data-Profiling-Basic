# %% [markdown]
# <a href="https://colab.research.google.com/github/Foysal348/Y-Data-Profiling-Basic/blob/main/YData_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/bangladesh_student_performance.csv")
df
# Out:
#             date gender  age address famsize   Pstatus  M_Edu  F_Edu  \
# 0     29/04/2018      M   18   Rural     GT3  Together      3      2
# 1     29/04/2018      F   19   Rural     LE3     Apart      0      4
# 2     29/04/2018      F   19   Rural     GT3  Together      0      3
# 3     29/04/2018      F   19   Rural     LE3     Apart      2      3
# 4     29/04/2018      M   17   Rural     GT3  Together      1      1
# ...          ...    ...  ...     ...     ...       ...    ...    ...
# 2013  29/04/2018      M   18   Urban     GT3  Together      2      2
# 2014  29/04/2018      M   19   Urban     GT3  Together      0      3
# 2015  29/04/2018      M   18   Urban     GT3  Together      3      2
# 2016  29/04/2018      M   19   Rural     GT3  Together      0      2
# 2017  29/04/2018      F   18   Rural     LE3  Together      0      2
#
#          M_Job     F_Job relationship smoker  tuition_fee  time_friends  \
# ...

# %% [markdown]
# ## Y Data Profiling/Pandas Profiling

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Bangladeshi Student Performance Prediction!",
    explorative=True
)

profile.to_file("Ydata.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
